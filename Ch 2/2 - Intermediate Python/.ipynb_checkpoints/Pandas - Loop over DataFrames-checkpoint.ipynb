# %%
# Loop over DataFrame
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Iterate over rows of cars
for lab, row in cars.iterrows() :
    print(lab)
    print(row)
    
print("************************************************************")

# Adapt for loop
for lab, row in cars.iterrows() :
    print(str(lab) + ": " + str(row['cars_per_cap']))
    
print("************************************************************")

# Add a column to a DataFrame
# Code for loop that adds COUNTRY column
for lab, row in cars.iterrows() :
    cars.loc[lab, "COUNTRY"] = row['country'].upper()

# Print cars
print(cars)

print("************************************************************")

# Replace for loop with a 1 liner - instead use .apply(str.upper)
#for lab, row in cars.iterrows() :
#    cars.loc[lab, "COUNTRY"] = row["country"].upper()
cars["COUNTRY"] = cars['country'].apply(str.upper)

print(cars)
# Out:
# US
# cars_per_cap              809
# country         United States
# drives_right             True
# Unnamed: 4                NaN
# Name: US, dtype: object
# AUS
# cars_per_cap          731
# country         Australia
# drives_right        False
# Unnamed: 4            NaN
# Name: AUS, dtype: object
# JAP
# cars_per_cap      588
# country         Japan
# drives_right    False
# Unnamed: 4        NaN
# Name: JAP, dtype: object
# IN
# cars_per_cap       18
# country         India
# drives_right    False
# Unnamed: 4        NaN
# Name: IN, dtype: object
# RU
# cars_per_cap       200
# country         Russia
# drives_right      True
# Unnamed: 4         NaN
# Name: RU, dtype: object
# MOR
# cars_per_cap         70
# country         Morocco
# drives_right       True
# Unnamed: 4          NaN
# Name: MOR, dtype: object
# EG
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Unnamed: 4        NaN
# Name: EG, dtype: object
# ************************************************************
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45
# ************************************************************
#        cars_per_cap        country  drives_right  Unnamed: 4        COUNTRY
# index
# US              809  United States          True         NaN  UNITED STATES
# AUS             731      Australia         False         NaN      AUSTRALIA
# JAP             588          Japan         False         NaN          JAPAN
# IN               18          India         False         NaN          INDIA
# RU              200         Russia          True         NaN         RUSSIA
# MOR              70        Morocco          True         NaN        MOROCCO
# EG               45          Egypt          True         NaN          EGYPT
